# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/grouping-and-sorting).**
#
# ---

# %% [markdown]
# # Introduction
#
# In these exercises we'll apply groupwise analysis to our dataset.
#
# Run the code cell below to load the data before running the exercises.

# %%
import pandas as pd

reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
#pd.set_option("display.max_rows", 5)

from learntools.core import binder; binder.bind(globals())
from learntools.pandas.grouping_and_sorting import *
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
# Who are the most common wine reviewers in the dataset? Create a `Series` whose index is the `taster_twitter_handle` category from the dataset, and whose values count how many reviews each person wrote.

# %%
# Your code here
reviews_written = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()

# Check your answer
q1.check()
# Out:
# Correct:
#
#
# ```python
# reviews_written = reviews.groupby('taster_twitter_handle').size()
# ```
# or
# ```python
# reviews_written = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()
# ```

# %%
reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: taster_twitter_handle, dtype: int64

# %%
#q1.hint()
#q1.solution()

# %% [markdown]
# ## 2.
# What is the best wine I can buy for a given amount of money? Create a `Series` whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that `4.0` dollars is at the top and `3300.0` dollars is at the bottom).

# %%
best_rating_per_price = reviews.groupby('price').points.max()

# Check your answer
q2.check()
# Out:
# Correct

# %%
reviews.groupby('price').points.max()
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
# What are the minimum and maximum prices for each `variety` of wine? Create a `DataFrame` whose index is the `variety` category from the dataset and whose values are the `min` and `max` values thereof.

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# ## 4.
# What are the most expensive wine varieties? Create a variable `sorted_varieties` containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
#reviews.variety.describe()

# %%
#reviews.groupby('variety').price.max().sort_values(ascending=False )

# %%
#reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.price.notnull().idxmax()])

# %%
reviews.groupby(['variety']).apply(lambda df: df.loc[df.price.notnull().idxmax()]).sort_values(by='price',ascending=False )
# Out:
#                                   country  \
# variety
# Ramisco                          Portugal
# Muscadelle                      Australia
# Muscat                          Australia
# Terrantez                        Portugal
# Shiraz-Viognier                 Australia
# ...                                   ...
# Roscetto                            Italy
# Sauvignon Blanc-Sauvignon Gris     France
# Tempranillo-Malbec              Argentina
# Vital                            Portugal
# Zelen                            Slovenia
#
#                                                                       description  \
# variety
# Ramisco                         This rare survival comes from Ramisco grapes p...
# Muscadelle                      This deep brown wine smells like a damp, mossy...
# Muscat                          This wine contains some material over 100 year...
# Terrantez                       Here is a remarkable rarity. The Terrantez gra...
# Shiraz-Viognier                 RunRig is always complex, and the 2012 doesn't...
# ...                                                                           ...
# Roscetto                        Roscetto, a little-known white grape from cent...
# Sauvignon Blanc-Sauvignon Gris  There is an attractive herbaceous character to...
# Tempranillo-Malbec              Unique for Argentina is this type of blend, wh...
# Vital                           Made from old Vital vines, this is a rich, bea...
# Zelen                           Honey and orange rind notes meld with a hint o...
#
#                                            designation  points  price  \
# variety
# Ramisco                                  Reserva Velho      93  495.0
# Muscadelle                                        Rare      98  350.0
# Muscat                                            Rare     100  350.0
# Terrantez                                          NaN      95  236.0
# Shiraz-Viognier                                 RunRig      97  225.0
# ...                                                ...     ...    ...
# Roscetto                                     Ferentano      88    NaN
# Sauvignon Blanc-Sauvignon Gris                  Presto      86    NaN
# Tempranillo-Malbec                           Alfa Crux      91    NaN
# Vital                           Casal Figueira António      90    NaN
# Zelen                                     Petite Burja      88    NaN
#
#                                         province           region_1 region_2  \
# variety
# Ramisco                                  Colares                NaN      NaN
# Muscadelle                              Victoria         Rutherglen      NaN
# Muscat                                  Victoria         Rutherglen      NaN
# Terrantez                                Madeira                NaN      NaN
# Shiraz-Viognier                  South Australia            Barossa      NaN
# ...                                          ...                ...      ...
# Roscetto                           Central Italy              Lazio      NaN
# Sauvignon Blanc-Sauvignon Gris  Southwest France  Côtes de Gascogne      NaN
# Tempranillo-Malbec              Mendoza Province         Uco Valley      NaN
# Vital                                     Lisboa                NaN      NaN
# Zelen                            Vipavska Dolina                NaN      NaN
#
#                                        taster_name taster_twitter_handle  \
# variety
# Ramisco                                 Roger Voss            @vossroger
# Muscadelle                          Joe Czerwinski                @JoeCz
# Muscat                              Joe Czerwinski                @JoeCz
# Terrantez                               Roger Voss            @vossroger
# Shiraz-Viognier                     Joe Czerwinski                @JoeCz
# ...                                            ...                   ...
# Roscetto                                       NaN                   NaN
# Sauvignon Blanc-Sauvignon Gris          Roger Voss            @vossroger
# Tempranillo-Malbec               Michael Schachner           @wineschach
# Vital                                   Roger Voss            @vossroger
# Zelen                           Anna Lee C. Iijima                   NaN
#
#                                                                             title  \
# variety
# Ramisco                         Adega Viuva Gomes 1934 Reserva Velho Red (Cola...
# Muscadelle                      Chambers Rosewood Vineyards NV Rare Muscadelle...
# Muscat                          Chambers Rosewood Vineyards NV Rare Muscat (Ru...
# Terrantez                                           Blandy's 1980 White (Madeira)
# Shiraz-Viognier                    Torbreck 2012 RunRig Shiraz-Viognier (Barossa)
# ...                                                                           ...
# Roscetto                                  Falesco 2008 Ferentano Roscetto (Lazio)
# Sauvignon Blanc-Sauvignon Gris  Domaine Seailles 2014 Presto Sauvignon Blanc-S...
# Tempranillo-Malbec              O. Fournier 2006 Alfa Crux Tempranillo-Malbec ...
# Vital                           Obrigado 2012 Casal Figueira António Vital (Li...
# Zelen                             Burja 2011 Petite Burja Zelen (Vipavska Dolina)
#
#                                                        variety  \
# variety
# Ramisco                                                Ramisco
# Muscadelle                                          Muscadelle
# Muscat                                                  Muscat
# Terrantez                                            Terrantez
# Shiraz-Viognier                                Shiraz-Viognier
# ...                                                        ...
# Roscetto                                              Roscetto
# Sauvignon Blanc-Sauvignon Gris  Sauvignon Blanc-Sauvignon Gris
# Tempranillo-Malbec                          Tempranillo-Malbec
# Vital                                                    Vital
# Zelen                                                    Zelen
#
#                                                      winery
# variety
# Ramisco                                   Adega Viuva Gomes
# Muscadelle                      Chambers Rosewood Vineyards
# Muscat                          Chambers Rosewood Vineyards
# Terrantez                                          Blandy's
# Shiraz-Viognier                                    Torbreck
# ...                                                     ...
# Roscetto                                            Falesco
# Sauvignon Blanc-Sauvignon Gris             Domaine Seailles
# Tempranillo-Malbec                              O. Fournier
# Vital                                              Obrigado
# Zelen                                                 Burja
#
# [707 rows x 13 columns]

# %%
sorted_varieties = price_extremes.sort_values(by=['min', 'max'], ascending=False)
# Check your answer
q4.check()
# Out:
# Correct

# %%
q4.hint()
q4.solution()
# Out:
# Hint: Use `sort_values()`, and provide a list of names to sort by.
# Solution:
# ```python
# sorted_varieties = price_extremes.sort_values(by=['min', 'max'], ascending=False)
# ```

# %%
price_extremes
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %%
price_extremes.sort_values(by=['min', 'max'], ascending=False)
# Out:
#                                   min    max
# variety
# Ramisco                         495.0  495.0
# Terrantez                       236.0  236.0
# Francisa                        160.0  160.0
# Rosenmuskateller                150.0  150.0
# Tinta Negra Mole                112.0  112.0
# ...                               ...    ...
# Roscetto                          NaN    NaN
# Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# Tempranillo-Malbec                NaN    NaN
# Vital                             NaN    NaN
# Zelen                             NaN    NaN
#
# [707 rows x 2 columns]

# %% [markdown]
# ## 5.
# Create a `Series` whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the `taster_name` and `points` columns.

# %%
reviews.groupby('taster_name').points.mean()
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64

# %%
reviewer_mean_ratings = reviews.groupby('taster_name').points.mean()

# Check your answer
q5.check()
# Out:
# Correct

# %%
#q5.hint()
#q5.solution()

# %% [markdown]
# Are there significant differences in the average scores assigned by the various reviewers? Run the cell below to use the `describe()` method to see a summary of the range of values.

# %% [markdown]
# ## 6.
# What combination of countries and varieties are most common? Create a `Series` whose index is a `MultiIndex`of `{country, variety}` pairs. For example, a pinot noir produced in the US should map to `{"US", "Pinot Noir"}`. Sort the values in the `Series` in descending order based on wine count.

# %%
reviews.groupby(['country', 'variety']).variety.count().sort_values(ascending = False)
# Out:
# country  variety
# US       Pinot Noir                  9885
#          Cabernet Sauvignon          7315
#          Chardonnay                  6801
# France   Bordeaux-style Red Blend    4725
# Italy    Red Blend                   3624
#                                      ...
# Mexico   Cinsault                       1
#          Grenache                       1
#          Merlot                         1
#          Rosado                         1
# Uruguay  White Blend                    1
# Name: variety, Length: 1612, dtype: int64

# %%
country_variety_counts = reviews.groupby(['country', 'variety']).variety.count().sort_values(ascending = False)

# Check your answer
q6.check()
# Out:
# Correct

# %%
#q6.hint()
q6.solution()
# Out:
# Solution:
# ```python
# country_variety_counts = reviews.groupby(['country', 'variety']).size().sort_values(ascending=False)
# ```

# %% [markdown]
# # Keep going
#
# Move on to the [**data types and missing data**](https://www.kaggle.com/residentmario/data-types-and-missing-values).

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/pandas/discussion) to chat with other learners.*
